# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
Name = 'JonathanMarks'
Pace = 'Flex'
Instructor = 'MorganJones'
BlogPost = []

# %% [markdown]
# # Business Problem
# My task was to come up with 3 recommendations for Microsoft in connection with its interest in entering the film market and producing original content.

# %% [markdown]
# # Data Understanding
# we were provided with data from several different sources: Box Office Mojo, Rotten Tomatoes, the IMDB, TMDB and TN.  The data sets were of different sorts and contained different information.  IMDB was the only SQL/relational database; all the others were either comma or tab separated formats.  The concentration of the IMDB database was on the people associated with the movie.  The concentration of the Box office Mojo and TN data were on the financial aspects of the movies.  The concentration of the Rotten Tomatoes and TMDB data were on the fan ratings and other specifics of the movies.

# %%
import pandas as pd
import sqlite3

# %%
#Reading in data and initial exploratory analysis.
df = pd.read_csv("C:\\Users\\jmark\\Documents\\Flatiron\\phase_1_project\\tmdb.movies.csv")

# %%
df.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
df2 = pd.read_csv("C:\\Users\\jmark\\Documents\\Flatiron\\phase_1_project\\bom.movie_gross.csv")

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
df3 = pd.read_csv("C:\\Users\\jmark\\Documents\\Flatiron\\phase_1_project\\tn.movie_budgets.csv.gz")

# %%
df3.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
import sqlite3 
conn = sqlite3.connect("C:\\Users\\jmark\\Documents\\Flatiron\\phase_1_project\\im.db")

# %%
conn = sqlite3.connect("C:\\Users\\jmark\\Documents\\Flatiron\\phase_1_project\\im.db")

# %%
pd.read_sql("""
SELECT *
  FROM persons;
""", conn)
# Out:
#         person_id         primary_name  birth_year  death_year  \
# 0       nm0061671    Mary Ellen Bauder         NaN         NaN
# 1       nm0061865         Joseph Bauer         NaN         NaN
# 2       nm0062070           Bruce Baum         NaN         NaN
# 3       nm0062195         Axel Baumann         NaN         NaN
# 4       nm0062798          Pete Baxter         NaN         NaN
# ...           ...                  ...         ...         ...
# 606643  nm9990381         Susan Grobes         NaN         NaN
# 606644  nm9990690          Joo Yeon So         NaN         NaN
# 606645  nm9991320       Madeline Smith         NaN         NaN
# 606646  nm9991786  Michelle Modigliani         NaN         NaN
# 606647  nm9993380       Pegasus Envoyé         NaN         NaN
#
#                                       primary_profession
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# 2                             miscellaneous,actor,writer
# 3       camera_department,cinematographer,art_department
# 4       production_designer,art_department,set_decorator
# ...                                                  ...
# 606643                                           actress
# 606644                                           actress
# 606645                                           actress
# 606646                                          producer
# 606647                             director,actor,writer
#
# [606648 rows x 5 columns]

# %%
q = pd.read_sql("""
SELECT *
  FROM movie_basics;
""", conn)

# %%
pd.read_sql("""
SELECT *
  FROM movie_akas;
""", conn)
# Out:
#          movie_id  ordering                                    title region  \
# 0       tt0369610        10                            Джурасик свят     BG
# 1       tt0369610        11                        Jurashikku warudo     JP
# 2       tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3       tt0369610        13                  O Mundo dos Dinossauros     BR
# 4       tt0369610        14                           Jurassic World     FR
# ...           ...       ...                                      ...    ...
# 331698  tt9827784         2                       Sayonara kuchibiru   None
# 331699  tt9827784         3                            Farewell Song    XWW
# 331700  tt9880178         1                              La atención   None
# 331701  tt9880178         2                              La atención     ES
# 331702  tt9880178         3                            The Attention    XWW
#
#        language        types   attributes  is_original_title
# 0            bg         None         None                0.0
# 1          None  imdbDisplay         None                0.0
# 2          None  imdbDisplay         None                0.0
# 3          None         None  short title                0.0
# 4          None  imdbDisplay         None                0.0
# ...         ...          ...          ...                ...
# 331698     None     original         None                1.0
# 331699       en  imdbDisplay         None                0.0
# 331700     None     original         None                1.0
# 331701     None         None         None                0.0
# 331702       en  imdbDisplay         None                0.0
#
# [331703 rows x 8 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
df2.describe()
# Out:
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %%
#Dropping rows with null values as still have large dataset without them.
df2drop = df2.dropna()

# %%
df2drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2007 entries, 0 to 3353
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           2007 non-null   object
#  1   studio          2007 non-null   object
#  2   domestic_gross  2007 non-null   float64
#  3   foreign_gross   2007 non-null   object
#  4   year            2007 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 94.1+ KB

# %%
#Changing datatypes to numeric to increase workability.

# %%
df2_1 = pd.to_numeric(df2['foreign_gross'], errors = 'coerce')

# %%
df2['foreign_gross'] = df2_1

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2032 non-null   float64
#  4   year            3387 non-null   int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 132.4+ KB

# %%
df2.describe()
# Out:
#        domestic_gross  foreign_gross         year
# count    3.359000e+03   2.032000e+03  3387.000000
# mean     2.874585e+07   7.505704e+07  2013.958075
# std      6.698250e+07   1.375294e+08     2.478141
# min      1.000000e+02   6.000000e+02  2010.000000
# 25%      1.200000e+05   3.775000e+06  2012.000000
# 50%      1.400000e+06   1.890000e+07  2014.000000
# 75%      2.790000e+07   7.505000e+07  2016.000000
# max      9.367000e+08   9.605000e+08  2018.000000

# %% [markdown]
# # Data Analysis

# %%
#Find which studios produce movies.
df2['studio'].unique()
# Out:
# array(['BV', 'WB', 'P/DW', 'Sum.', 'Par.', 'Uni.', 'Fox', 'Wein.', 'Sony',
#        'FoxS', 'SGem', 'WB (NL)', 'LGF', 'MBox', 'CL', 'W/Dim.', 'CBS',
#        'Focus', 'MGM', 'Over.', 'Mira.', 'IFC', 'CJ', 'NM', 'SPC', 'ParV',
#        'Gold.', 'JS', 'RAtt.', 'Magn.', 'Free', '3D', 'UTV', 'Rela.',
#        'Zeit.', 'Anch.', 'PDA', 'Lorb.', 'App.', 'Drft.', 'Osci.', 'IW',
#        'Rog.', nan, 'Eros', 'Relbig.', 'Viv.', 'Hann.', 'Strand', 'NGE',
#        'Scre.', 'Kino', 'Abr.', 'CZ', 'ATO', 'First', 'GK', 'FInd.',
#        'NFC', 'TFC', 'Pala.', 'Imag.', 'NAV', 'Arth.', 'CLS', 'Mont.',
#        'Olive', 'CGld', 'FOAK', 'IVP', 'Yash', 'ICir', 'FM', 'Vita.',
#        'WOW', 'Truly', 'Indic.', 'FD', 'Vari.', 'TriS', 'ORF', 'IM',
#        'Elev.', 'Cohen', 'NeoC', 'Jan.', 'MNE', 'Trib.', 'Rocket',
#        'OMNI/FSR', 'KKM', 'Argo.', 'SMod', 'Libre', 'FRun', 'WHE', 'P4',
#        'KC', 'SD', 'AM', 'MPFT', 'Icar.', 'AGF', 'A23', 'Da.', 'NYer',
#        'Rialto', 'DF', 'KL', 'ALP', 'LG/S', 'WGUSA', 'MPI', 'RTWC', 'FIP',
#        'RF', 'ArcEnt', 'PalUni', 'EpicPics', 'EOne', 'LD', 'AF', 'TFA',
#        'Myr.', 'BM&DH', 'SEG', 'PalT', 'Outs', 'OutF', 'BSM', 'WAMCR',
#        'PM&E', 'A24', 'Cdgm.', 'Distrib.', 'Imax', 'PH', 'HTR', 'ELS',
#        'PI', 'E1', 'TVC', 'FEF', 'EXCL', 'MSF', 'P/108', 'FCW', 'XL',
#        'Shout!', 'SV', 'CE', 'VPD', 'KE', 'Saban', 'CF&SR', 'Triu', 'DR',
#        'Crnth', 'Ampl.', 'CP', 'Proud', 'BGP', 'Abk.', 'DLA', 'B360',
#        'BWP', 'SEA', 'RME', 'KS', 'VE', 'LGP', 'EC', 'FUN', 'STX', 'AR',
#        'BG', 'PFR', 'BST', 'BH Tilt', 'BSC', 'U/P', 'UHE', 'CLF', 'FR',
#        'AaF', 'Orch.', 'Alc', 'PBS', 'SHO', 'Grav.', 'Gathr', 'Asp.',
#        'ADC', 'Rel.', 'SM', 'AZ', 'UEP', 'ITL', 'TA', 'MR', 'BBC',
#        'CFilms', 'Part.', 'FOR', 'TAFC', 'JBG', 'PNT', 'CineGalaxy',
#        'Fathom', 'Zee', 'Men.', 'YFG', 'Gaatri', 'Mon', 'Ghop',
#        'Cleopatra', 'Dreamwest', 'SDS', 'Linn', 'Electric', 'Jampa', 'HC',
#        'GrtIndia', 'Neon', 'ENTMP', 'Good Deed', 'ParC', 'Aviron',
#        'Annapurna', 'Amazon', 'Affirm', 'MOM', 'Orion', 'CFI', 'UTMW',
#        'Crimson', 'CAVU', 'EF', 'Arrow', 'Hiber', 'Studio 8',
#        'Global Road', 'Trafalgar', 'Greenwich', 'Spanglish', 'Blue Fox',
#        'RLJ', 'Swen', 'PackYourBag', 'Gaum.', 'Grindstone',
#        'Conglomerate', 'MUBI', 'Darin Southa', 'Super', 'CARUSEL', 'PDF',
#        'Synergetic'], dtype=object)

# %%
#See the distribution of films by studio
df2studios= df2['studio'].value_counts().head(20)

# %%
df2studios
# Out:
# IFC       166
# Uni.      147
# WB        140
# Fox       136
# Magn.     136
# SPC       123
# Sony      110
# BV        106
# LGF       103
# Par.      101
# Eros       89
# Wein.      77
# CL         74
# Strand     68
# FoxS       67
# RAtt.      66
# KL         62
# Focus      60
# WGUSA      58
# CJ         56
# Name: studio, dtype: int64

# %%
df2studios.plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
sum(df2['domestic_gross'])
# Out:
# nan

# %%
sum(df2.dropna()['domestic_gross'])
# Out:
# 91522019285.0

# %%
#convert foreign_gross from object type to float.

df2_1 = pd.to_numeric(df2['foreign_gross'], errors = 'coerce')

# %%
df2['foreign_gross']=df2_1

# %% [markdown]
# # estimate size of market by year. By conservative estimates, it is at least tens of billions of dollars.

# %%
df2.groupby('year').sum()
# Out:
#       domestic_gross  foreign_gross
# year
# 2010    1.015693e+10   1.437426e+10
# 2011    1.006416e+10   1.567099e+10
# 2012    1.087661e+10   1.703789e+10
# 2013    1.079233e+10   1.661239e+10
# 2014    1.033774e+10   1.697197e+10
# 2015    1.105141e+10   1.520395e+10
# 2016    1.125365e+10   1.911904e+10
# 2017    1.093327e+10   2.005093e+10
# 2018    1.109121e+10   1.747449e+10

# %%
df2.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#    foreign_gross  year
# 0    652000000.0  2010
# 1    691300000.0  2010
# 2    664300000.0  2010
# 3    535700000.0  2010
# 4    513900000.0  2010

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
df3.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
#Find the most popular genres.
q = pd.read_sql("""
SELECT *
  FROM movie_basics;
""", conn)
q2 = q.groupby('genres').count()
q2.sort_values('primary_title', ascending = False).head(25)
# Out:
#                                movie_id  primary_title  original_title  \
# genres
# Documentary                       32185          32185           32185
# Drama                             21486          21486           21486
# Comedy                             9177           9177            9177
# Horror                             4372           4372            4372
# Comedy,Drama                       3519           3519            3519
# Thriller                           3046           3046            3046
# Action                             2219           2219            2219
# Biography,Documentary              2115           2115            2115
# Drama,Romance                      2079           2079            2079
# Comedy,Drama,Romance               1558           1558            1558
# Documentary,Drama                  1554           1554            1554
# Comedy,Romance                     1507           1507            1507
# Romance                            1454           1454            1453
# Documentary,Music                  1365           1365            1365
# Drama,Thriller                     1335           1335            1335
# Documentary,History                1289           1289            1289
# Horror,Thriller                    1253           1253            1253
# Biography,Documentary,History      1230           1230            1230
# Biography,Documentary,Drama        1028           1028            1028
# Family                              939            939             939
# Animation                           828            828             828
# Drama,Family                        784            784             784
# Action,Crime,Drama                  727            727             727
# Comedy,Horror                       724            724             724
# Crime,Drama                         723            723             723
#
#                                start_year  runtime_minutes
# genres
# Documentary                         32185            24672
# Drama                               21486            15725
# Comedy                               9177             6413
# Horror                               4372             2975
# Comedy,Drama                         3519             3163
# Thriller                             3046             1924
# Action                               2219             1153
# Biography,Documentary                2115             2052
# Drama,Romance                        2079             1806
# Comedy,Drama,Romance                 1558             1451
# Documentary,Drama                    1554             1515
# Comedy,Romance                       1507             1302
# Romance                              1454              811
# Documentary,Music                    1365             1265
# Drama,Thriller                       1335             1178
# Documentary,History                  1289             1245
# Horror,Thriller                      1253             1087
# Biography,Documentary,History        1230             1212
# Biography,Documentary,Drama          1028             1009
# Family                                939              633
# Animation                             828              510
# Drama,Family                          784              733
# Action,Crime,Drama                    727              656
# Comedy,Horror                         724              599
# Crime,Drama                           723              641

# %%
q2_1 = q2.sort_values('movie_id', ascending = False).head(7)
q2_1
# Out:
#               movie_id  primary_title  original_title  start_year  \
# genres
# Documentary      32185          32185           32185       32185
# Drama            21486          21486           21486       21486
# Comedy            9177           9177            9177        9177
# Horror            4372           4372            4372        4372
# Comedy,Drama      3519           3519            3519        3519
# Thriller          3046           3046            3046        3046
# Action            2219           2219            2219        2219
#
#               runtime_minutes
# genres
# Documentary             24672
# Drama                   15725
# Comedy                   6413
# Horror                   2975
# Comedy,Drama             3163
# Thriller                 1924
# Action                   1153

# %%
q2_2 = q2_1.loc[:, 'movie_id']

# %%
q2_2.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='genres'>

# %%
#Find out what genres get the highest ratings.
q3 = """SELECT mb.genres, mr.averagerating, mr.numvotes
        FROM movie_basics as mb
        JOIN movie_ratings as mr
            ON mb.movie_id = mr.movie_id
        GROUP BY mb.genres
        ORDER BY mr.averagerating DESC
        LIMIT 30"""
pd.read_sql(q3,conn)
# Out:
#                            genres  averagerating  numvotes
# 0      Documentary,Family,Romance            9.7        25
# 1        Comedy,Documentary,Sport            9.7        22
# 2      Comedy,Documentary,Fantasy            9.4         5
# 3      Documentary,Family,Musical            9.3        19
# 4                   History,Sport            9.2         5
# 5         Documentary,History,War            9.2        29
# 6         Crime,Documentary,Drama            9.2         8
# 7        Action,Documentary,Sport            9.2         8
# 8      Comedy,Documentary,Romance            9.1         7
# 9                             War            9.0         5
# 10                  Music,Mystery            9.0         5
# 11                      Game-Show            9.0         7
# 12         Documentary,Family,War            9.0         5
# 13                    History,War            8.9        11
# 14      Comedy,Documentary,Family            8.9         7
# 15      Adventure,Biography,Crime            8.9        41
# 16                    Drama,Short            8.8         8
# 17              Drama,Fantasy,War            8.8        22
# 18         Documentary,News,Sport            8.8        25
# 19    Documentary,News,Reality-TV            8.8         8
# 20     Documentary,Drama,Thriller            8.8         8
# 21        Comedy,Drama,Reality-TV            8.8        15
# 22     Comedy,Documentary,Mystery            8.8        21
# 23            Biography,Drama,War            8.8        12
# 24   Adventure,Comedy,Documentary            8.8        24
# 25          Drama,Fantasy,Musical            8.7         7
# 26            Documentary,Western            8.7        20
# 27    Documentary,History,Western            8.7        15
# 28      Crime,Documentary,History            8.7        46
# 29  Biography,Documentary,Musical            8.7         6

# %%
df7 = pd.read_csv("C:\\Users\\jmark\\Documents\\Flatiron\\phase_1_project\\rt.movie_info.tsv", '\t')
# Out:
# C:\Users\jmark\AppData\Local\Temp\ipykernel_22856\480480316.py:1: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   df7 = pd.read_csv("C:\\Users\\jmark\\Documents\\Flatiron\\phase_1_project\\rt.movie_info.tsv", '\t')

# %%
df7.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                   Allison Anders  Sep 13, 1996  Apr 18, 2000      NaN
# 3  Paul Attanasio|Michael Crichton   Dec 9, 1994  Aug 27, 1997      NaN
# 4                     Giles Cooper           NaN           NaN      NaN
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One
# 2        NaN  116 minutes                NaN
# 3        NaN  128 minutes                NaN
# 4        NaN  200 minutes                NaN

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1560 non-null   int64
#  1   synopsis      1498 non-null   object
#  2   rating        1557 non-null   object
#  3   genre         1552 non-null   object
#  4   director      1361 non-null   object
#  5   writer        1111 non-null   object
#  6   theater_date  1201 non-null   object
#  7   dvd_date      1201 non-null   object
#  8   currency      340 non-null    object
#  9   box_office    340 non-null    object
#  10  runtime       1530 non-null   object
#  11  studio        494 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 146.4+ KB

# %%
# Out:
# array(['R', 'NR', 'PG', 'PG-13', nan, 'G', 'NC17'], dtype=object)

# %%
# Out:
# R        521
# NR       503
# PG       240
# PG-13    235
# G         57
# NC17       1
# Name: rating, dtype: int64

# %%
df3
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
#Change monetary information from strings to numeric.

df3["production_budget"] = df3["production_budget"].replace("[$,]", "", regex=True).astype(int)
df3["domestic_gross"] = df3["domestic_gross"].replace("[$,]", "", regex=True).astype(int)

# %%
df3["worldwide_gross"] = df3["worldwide_gross"].replace("[$,]", "", regex=True).astype(float)

# %%
df3.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross
# 0          425000000       760507625     2.776345e+09
# 1          410600000       241063875     1.045664e+09
# 2          350000000        42762350     1.497624e+08
# 3          330600000       459005868     1.403014e+09
# 4          317000000       620181382     1.316722e+09

# %%
#Summary statistics for costs and revenues.
df3.describe()
# Out:
#                 id  production_budget  domestic_gross  worldwide_gross
# count  5782.000000       5.782000e+03    5.782000e+03     5.782000e+03
# mean     50.372363       3.158776e+07    4.187333e+07     9.148746e+07
# std      28.821076       4.181208e+07    6.824060e+07     1.747200e+08
# min       1.000000       1.100000e+03    0.000000e+00     0.000000e+00
# 25%      25.000000       5.000000e+06    1.429534e+06     4.125415e+06
# 50%      50.000000       1.700000e+07    1.722594e+07     2.798445e+07
# 75%      75.000000       4.000000e+07    5.234866e+07     9.764584e+07
# max     100.000000       4.250000e+08    9.366622e+08     2.776345e+09

# %%
df3
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross
# 0             425000000       760507625     2.776345e+09
# 1             410600000       241063875     1.045664e+09
# 2             350000000        42762350     1.497624e+08
# 3             330600000       459005868     1.403014e+09
# 4             317000000       620181382     1.316722e+09
# ...                 ...             ...              ...
# 5777               7000               0     0.000000e+00
# 5778               6000           48482     2.404950e+05
# 5779               5000            1338     1.338000e+03
# 5780               1400               0     0.000000e+00
# 5781               1100          181041     1.810410e+05
#
# [5782 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
#Check correlation between production budget and sales


df3.drop('id', axis=1)
# Out:
#       release_date                                        movie  \
# 0     Dec 18, 2009                                       Avatar
# 1     May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      Jun 7, 2019                                 Dark Phoenix
# 3      May 1, 2015                      Avengers: Age of Ultron
# 4     Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...            ...                                          ...
# 5777  Dec 31, 2018                                       Red 11
# 5778   Apr 2, 1999                                    Following
# 5779  Jul 13, 2005                Return to the Land of Wonders
# 5780  Sep 29, 2015                         A Plague So Pleasant
# 5781   Aug 5, 2005                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross
# 0             425000000       760507625     2.776345e+09
# 1             410600000       241063875     1.045664e+09
# 2             350000000        42762350     1.497624e+08
# 3             330600000       459005868     1.403014e+09
# 4             317000000       620181382     1.316722e+09
# ...                 ...             ...              ...
# 5777               7000               0     0.000000e+00
# 5778               6000           48482     2.404950e+05
# 5779               5000            1338     1.338000e+03
# 5780               1400               0     0.000000e+00
# 5781               1100          181041     1.810410e+05
#
# [5782 rows x 5 columns]

# %%
df3.plot('production_budget', 'domestic_gross', kind='scatter')
# Out:
# <AxesSubplot:xlabel='production_budget', ylabel='domestic_gross'>

# %% [markdown]
# df3.info()

# %%
df3.plot('production_budget', 'worldwide_gross', kind='scatter')
# Out:
# <AxesSubplot:xlabel='production_budget', ylabel='worldwide_gross'>

# %%
#There is some correlation between production budget and sales, especially internationally, but many lower budget movies have higher sales as well.

# %%
df3.plot('domestic_gross', 'worldwide_gross', kind='scatter')
# Out:
# <AxesSubplot:xlabel='domestic_gross', ylabel='worldwide_gross'>

# %%
df3['profits'] = df3['worldwide_gross']-df3['production_budget']

# %%
df3.plot('production_budget', 'profits', kind='scatter')
# Out:
# <AxesSubplot:xlabel='production_budget', ylabel='profits'>

# %%
#There is some correlation between production budget and profits, but many lower budget movies have substantial profits.

# %%
df7.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                   Allison Anders  Sep 13, 1996  Apr 18, 2000      NaN
# 3  Paul Attanasio|Michael Crichton   Dec 9, 1994  Aug 27, 1997      NaN
# 4                     Giles Cooper           NaN           NaN      NaN
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One
# 2        NaN  116 minutes                NaN
# 3        NaN  128 minutes                NaN
# 4        NaN  200 minutes                NaN

# %%
df2.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#    foreign_gross  year
# 0    652000000.0  2010
# 1    691300000.0  2010
# 2    664300000.0  2010
# 3    535700000.0  2010
# 4    513900000.0  2010

# %%
df7.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                   Allison Anders  Sep 13, 1996  Apr 18, 2000      NaN
# 3  Paul Attanasio|Michael Crichton   Dec 9, 1994  Aug 27, 1997      NaN
# 4                     Giles Cooper           NaN           NaN      NaN
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One
# 2        NaN  116 minutes                NaN
# 3        NaN  128 minutes                NaN
# 4        NaN  200 minutes                NaN

# %%
df8 = df7.dropna()

# %%
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 235 entries, 1 to 1545
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            235 non-null    int64
#  1   synopsis      235 non-null    object
#  2   rating        235 non-null    object
#  3   genre         235 non-null    object
#  4   director      235 non-null    object
#  5   writer        235 non-null    object
#  6   theater_date  235 non-null    object
#  7   dvd_date      235 non-null    object
#  8   currency      235 non-null    object
#  9   box_office    235 non-null    object
#  10  runtime       235 non-null    object
#  11  studio        235 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 23.9+ KB

# %%
#converting sales from string to numeric.
df8["box_office"] = df8["box_office"].replace("[$,]", "", regex=True).astype(float)
# Out:
# C:\Users\jmark\AppData\Local\Temp\ipykernel_22856\3001582604.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df8["box_office"] = df8["box_office"].replace("[$,]", "", regex=True).astype(float)

# %%
#Find which ratings categories do best at box office.
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 235 entries, 1 to 1545
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            235 non-null    int64
#  1   synopsis      235 non-null    object
#  2   rating        235 non-null    object
#  3   genre         235 non-null    object
#  4   director      235 non-null    object
#  5   writer        235 non-null    object
#  6   theater_date  235 non-null    object
#  7   dvd_date      235 non-null    object
#  8   currency      235 non-null    object
#  9   box_office    235 non-null    float64
#  10  runtime       235 non-null    object
#  11  studio        235 non-null    object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 23.9+ KB

# %%
df9 =df8.groupby('rating').mean('box_office')
df9
# Out:
#                  id    box_office
# rating
# G       1368.400000  7.402788e+06
# NC17    1567.000000  1.260219e+06
# NR      1160.222222  6.376923e+05
# PG      1071.657895  5.289280e+07
# PG-13   1053.506494  6.872359e+07
# R        921.019048  2.394827e+07

# %% [markdown]
# PG-13, PG and R do best at box office.

# %%
df10 = df9.drop('id', axis=1)

# %%
df10.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='rating'>

# %%
#PG-13, PG and R do best at box office.  PG-13 has almost 3x as much sales as R.

# %% [markdown]
# df8.groupby(['rating','genre']).mean().head(40)

# %%
#Find the highest rated movies.
q7 = """SELECT mb.primary_title, mr.averagerating, mr.numvotes
        FROM movie_basics as mb
        JOIN movie_ratings as mr
            ON mb.movie_id = mr.movie_id
        ORDER BY mr.averagerating DESC
        LIMIT 30"""
pd.read_sql(q7,conn)
# Out:
#                                         primary_title  averagerating  numvotes
# 0      Exteriores: Mulheres Brasileiras na Diplomacia           10.0         5
# 1           The Dark Knight: The Ballad of the N Word           10.0         5
# 2                                Freeing Bernie Baran           10.0         5
# 3                               Hercule contre Hermès           10.0         5
# 4                               I Was Born Yesterday!           10.0         6
# 5                           Dog Days in the Heartland           10.0         5
# 6                                     Revolution Food           10.0         8
# 7                     Fly High: Story of the Disc Dog           10.0         7
# 8                                       All Around Us           10.0         6
# 9                 The Paternal Bond: Barbary Macaques           10.0         5
# 10                              Requiem voor een Boom           10.0         5
# 11    A Dedicated Life: Phoebe Brand Beyond the Group           10.0         5
# 12  Ellis Island: The Making of a Master Race in A...           10.0         6
# 13                                     Calamity Kevin           10.0         6
# 14                      Pick It Up! - Ska in the '90s           10.0         5
# 15                                           Renegade           10.0        20
# 16                                  Gini Helida Kathe            9.9       417
# 17         The Wedding Present: Something Left Behind            9.9         8
# 18                                        LA Foodways            9.9         8
# 19                                Moscow we will lose            9.9        18
# 20                                     Wild Karnataka            9.9        10
# 21                         Dreaming of a Vetter World            9.8         6
# 22  Grisaia: Phantom trigger the animation 02. Sou...            9.8         5
# 23                               Mujeres republicanas            9.8         5
# 24                          Send My Mail to Nashville            9.8         5
# 25                   Maasai 10th Lost Tribe of Israel            9.8         5
# 26                                     Our Friend Jon            9.8        28
# 27                                       Hiro's Table            9.8         5
# 28                  Pieces of Lives, Pieces of Dreams            9.8         6
# 29                             La Lección de Anatomía            9.8        28

# %%
#Find out the professionals/actors who have been voted most on by fans.
q8 = """SELECT p.primary_profession, p.primary_name, mr.averagerating, mr.numvotes
        FROM movie_ratings as mr
        JOIN known_for as kf
            ON mr.movie_id = kf.movie_id
        JOIN persons as p
            ON kf.person_id = p.person_id
        WHERE (primary_profession = 'actress' OR primary_profession = 'actor')
        ORDER BY mr.numvotes DESC
        LIMIT 30"""
pd.read_sql(q8, conn)
# Out:
#    primary_profession         primary_name  averagerating  numvotes
# 0               actor     Mark Fleischmann            8.8   1841066
# 1             actress         Claire Geare            8.8   1841066
# 2               actor        Wade Williams            8.4   1387769
# 3               actor        Oliver Cotton            8.4   1387769
# 4               actor         Cameron Jack            8.4   1387769
# 5               actor           Will Estes            8.4   1387769
# 6               actor          Uri Gavriel            8.4   1387769
# 7             actress            Aja Evans            8.4   1387769
# 8               actor         Mark Killeen            8.4   1387769
# 9               actor   Gualberto Del Toro            8.4   1387769
# 10              actor     Anthony Chisholm            8.4   1387769
# 11              actor      Zackary Kresser            8.4   1387769
# 12              actor          Nick Julian            8.4   1387769
# 13              actor   Lonell R. Childred            8.4   1387769
# 14              actor        Kevin Gurnari            8.4   1387769
# 15            actress       Sarah Goldberg            8.4   1387769
# 16            actress        Claire Julien            8.4   1387769
# 17              actor         Jeff Hephner            8.6   1299334
# 18            actress       Collette Wolfe            8.6   1299334
# 19              actor    Christopher Berry            8.4   1211405
# 20              actor          Kim Collins            8.4   1211405
# 21            actress       Samantha Smith            8.4   1211405
# 22              actor        Amari Cheatom            8.4   1211405
# 23            actress   Leianna Seals Bell            8.4   1211405
# 24            actress        Aleeah Rogers            8.4   1211405
# 25            actress  Sharon Pierre-Louis            8.4   1211405
# 26            actress      Rashia Whitlock            8.4   1211405
# 27              actor     Marcus Henderson            8.4   1211405
# 28            actress           Tina Benko            8.1   1183655
# 29            actress        Maria Perossa            8.1   1183655

# %%
#Find out the actors who have been voted highest on by fans.
q8 = """SELECT p.primary_profession, p.primary_name, mr.averagerating, mr.numvotes
        FROM movie_ratings as mr
        JOIN known_for as kf
            ON mr.movie_id = kf.movie_id
        JOIN persons as p
            ON kf.person_id = p.person_id
        WHERE (mr.numvotes > 50) AND (primary_profession = 'actress' OR primary_profession = 'actor')
        ORDER BY mr. averagerating DESC, mr.numvotes DESC
        LIMIT 30"""
pd.read_sql(q8, conn)
# Out:
#    primary_profession                primary_name  averagerating  numvotes
# 0               actor                        Loki            9.9       417
# 1               actor                Chris Scagos            9.7      5600
# 2               actor                  John Luder            9.7      5600
# 3               actor            Rafal Zawierucha            9.7      5600
# 4             actress          Jennifer Churchich            9.7      5600
# 5             actress             Dallas Chandler            9.7      5600
# 6             actress               Mikey Madison            9.7      5600
# 7             actress           Samantha Robinson            9.7      5600
# 8             actress           Courtney M. Moore            9.7      5600
# 9             actress  HaleyRae Christian Cannell            9.7      5600
# 10              actor              Jacob Antolini            9.7      5600
# 11            actress                     Neeraja            9.7       639
# 12              actor                     Gowtham            9.7       639
# 13              actor         Rezo Chkhikvishvili            9.6      2604
# 14              actor              Valeri Korshia            9.6      2604
# 15              actor           Gogi Turkiashvili            9.6      2604
# 16              actor                 Jano Izoria            9.6      2604
# 17              actor             Slava Natenadze            9.6      2604
# 18            actress               Ana Tsereteli            9.6      2604
# 19              actor          Otto Darchiashvili            9.6      2604
# 20            actress                      Harini            9.6       808
# 21              actor               Krishna Adiga            9.6       808
# 22              actor              Vinay Rajkumar            9.6       808
# 23            actress                 Latha Hegde            9.6       808
# 24              actor                    Dattanna            9.6       808
# 25              actor              P. Ravishankar            9.6       808
# 26              actor              Pratap Saurabh            9.6       624
# 27              actor            Preetyka Chauhan            9.6       624
# 28              actor             Aloknath Pathak            9.6       624
# 29              actor          Uddika Premarathna            9.5      6509

# %%
#First step to show actors/actresses in highest grossing movies: Join SQL IMDB tables in order to have actresses and movie in same table.
q10 = """SELECT mb.primary_title, p.primary_profession, p.primary_name, mr.averagerating, mr.numvotes
        FROM movie_ratings as mr
        JOIN movie_basics as mb
            ON mr.movie_id = mb.movie_id
        JOIN known_for as kf
            ON mr.movie_id = kf.movie_id
        JOIN persons as p
            ON kf.person_id = p.person_id
        WHERE (mr.numvotes > 50) AND (primary_profession = 'actress' OR primary_profession = 'actor')
        ORDER BY mr. averagerating DESC, mr.numvotes DESC"""
df12 = pd.read_sql(q10, conn)

# %%
df12.set_index('primary_title', inplace=True)

# %%
df3.set_index('movie', inplace=True)

# %%
#Last step to show actors/actresses in highest grossing movies: Join two data frames to add sales figures to actor/movie dataframe.
df_actorsSales = df3.join(df12, how = "inner")

# %%
df_actorsSalesSorted = df_actorsSales.sort_values('worldwide_gross', ascending = False).head(30)
df_actorsSalesSorted
# Out:
#                          id  release_date  production_budget  domestic_gross  \
# Avengers: Infinity War    7  Apr 27, 2018          300000000       678815482
# Avengers: Infinity War    7  Apr 27, 2018          300000000       678815482
# Avengers: Infinity War    7  Apr 27, 2018          300000000       678815482
# Avengers: Infinity War    7  Apr 27, 2018          300000000       678815482
# Avengers: Infinity War    7  Apr 27, 2018          300000000       678815482
# Avengers: Infinity War    7  Apr 27, 2018          300000000       678815482
# Avengers: Infinity War    7  Apr 27, 2018          300000000       678815482
# Avengers: Infinity War    7  Apr 27, 2018          300000000       678815482
# Avengers: Infinity War    7  Apr 27, 2018          300000000       678815482
# Jurassic World           34  Jun 12, 2015          215000000       652270625
# Jurassic World           34  Jun 12, 2015          215000000       652270625
# Jurassic World           34  Jun 12, 2015          215000000       652270625
# Jurassic World           34  Jun 12, 2015          215000000       652270625
# Jurassic World           34  Jun 12, 2015          215000000       652270625
# Jurassic World           34  Jun 12, 2015          215000000       652270625
# Furious 7                67   Apr 3, 2015          190000000       353007020
# Furious 7                67   Apr 3, 2015          190000000       353007020
# Furious 7                67   Apr 3, 2015          190000000       353007020
# Furious 7                67   Apr 3, 2015          190000000       353007020
# Furious 7                67   Apr 3, 2015          190000000       353007020
# Furious 7                67   Apr 3, 2015          190000000       353007020
# Furious 7                67   Apr 3, 2015          190000000       353007020
# Furious 7                67   Apr 3, 2015          190000000       353007020
# Furious 7                67   Apr 3, 2015          190000000       353007020
# The Avengers             27   May 4, 2012          225000000       623279547
# The Avengers             27   May 4, 2012          225000000       623279547
# Avengers: Age of Ultron   4   May 1, 2015          330600000       459005868
# Avengers: Age of Ultron   4   May 1, 2015          330600000       459005868
# Avengers: Age of Ultron   4   May 1, 2015          330600000       459005868
# Avengers: Age of Ultron   4   May 1, 2015          330600000       459005868
#
#                          worldwide_gross       profits primary_profession  \
# Avengers: Infinity War      2.048134e+09  1.748134e+09              actor
# Avengers: Infinity War      2.048134e+09  1.748134e+09              actor
# Avengers: Infinity War      2.048134e+09  1.748134e+09            actress
# Avengers: Infinity War      2.048134e+09  1.748134e+09              actor
# Avengers: Infinity War      2.048134e+09  1.748134e+09            actress
# Avengers: Infinity War      2.048134e+09  1.748134e+09            actress
# Avengers: Infinity War      2.048134e+09  1.748134e+09            actress
# Avengers: Infinity War      2.048134e+09  1.748134e+09              actor
# Avengers: Infinity War      2.048134e+09  1.748134e+09              actor
# Jurassic World              1.648855e+09  1.433855e+09            actress
# Jurassic World              1.648855e+09  1.433855e+09            actress
# Jurassic World              1.648855e+09  1.433855e+09            actress
# Jurassic World              1.648855e+09  1.433855e+09            actress
# Jurassic World              1.648855e+09  1.433855e+09            actress
# Jurassic World              1.648855e+09  1.433855e+09              actor
# Furious 7                   1.518723e+09  1.328723e+09              actor
# Furious 7                   1.518723e+09  1.328723e+09            actress
# Furious 7                   1.518723e+09  1.328723e+09            actress
# Furious 7                   1.518723e+09  1.328723e+09              actor
# Furious 7                   1.518723e+09  1.328723e+09            actress
# Furious 7                   1.518723e+09  1.328723e+09              actor
# Furious 7                   1.518723e+09  1.328723e+09            actress
# Furious 7                   1.518723e+09  1.328723e+09              actor
# Furious 7                   1.518723e+09  1.328723e+09            actress
# The Avengers                1.517936e+09  1.292936e+09            actress
# The Avengers                1.517936e+09  1.292936e+09            actress
# Avengers: Age of Ultron     1.403014e+09  1.072414e+09            actress
# Avengers: Age of Ultron     1.403014e+09  1.072414e+09            actress
# Avengers: Age of Ultron     1.403014e+09  1.072414e+09              actor
# Avengers: Age of Ultron     1.403014e+09  1.072414e+09            actress
#
#                                  primary_name  averagerating  numvotes
# Avengers: Infinity War           Winston Duke            8.5    670926
# Avengers: Infinity War            Ethan Dizon            8.5    670926
# Avengers: Infinity War        Pom Klementieff            8.5    670926
# Avengers: Infinity War     Tom Vaughan-Lawlor            8.5    670926
# Avengers: Infinity War           Danai Gurira            8.5    670926
# Avengers: Infinity War       Florence Kasumba            8.5    670926
# Avengers: Infinity War           Kerry Condon            8.5    670926
# Avengers: Infinity War          Bobby Hoskins            8.5    670926
# Avengers: Infinity War          Jacob Batalon            8.5    670926
# Jurassic World               Anna Talakkottur            7.0    539338
# Jurassic World                   Chloe Perrin            7.0    539338
# Jurassic World               Kelly Washington            7.0    539338
# Jurassic World           Courtney James Clark            7.0    539338
# Jurassic World                  Katie McGrath            7.0    539338
# Jurassic World                    Ty Simpkins            7.0    539338
# Furious 7                         Lucas Black            7.2    335074
# Furious 7                    Jordana Brewster            7.2    335074
# Furious 7                   Nathalie Emmanuel            7.2    335074
# Furious 7                           Ali Fazal            7.2    335074
# Furious 7                      Brittney Alger            7.2    335074
# Furious 7                        Gentry White            7.2    335074
# Furious 7                       Sasha Casares            7.2    335074
# Furious 7                      Adrian Lockett            7.2    335074
# Furious 7                   Tatiana Bukhahova            7.2    335074
# The Avengers                    Maria Perossa            8.1   1183655
# The Avengers                       Tina Benko            8.1   1183655
# Avengers: Age of Ultron          Edina Loskay            7.3    665594
# Avengers: Age of Ultron      Harriet Manamela            7.3    665594
# Avengers: Age of Ultron         Henry Goodman            7.3    665594
# Avengers: Age of Ultron         Ingvild Deila            7.3    665594

# %%
df_actorsSalesSorted.iloc[:,4:]
# Out:
#                          worldwide_gross       profits primary_profession  \
# Avengers: Infinity War      2.048134e+09  1.748134e+09              actor
# Avengers: Infinity War      2.048134e+09  1.748134e+09              actor
# Avengers: Infinity War      2.048134e+09  1.748134e+09            actress
# Avengers: Infinity War      2.048134e+09  1.748134e+09              actor
# Avengers: Infinity War      2.048134e+09  1.748134e+09            actress
# Avengers: Infinity War      2.048134e+09  1.748134e+09            actress
# Avengers: Infinity War      2.048134e+09  1.748134e+09            actress
# Avengers: Infinity War      2.048134e+09  1.748134e+09              actor
# Avengers: Infinity War      2.048134e+09  1.748134e+09              actor
# Jurassic World              1.648855e+09  1.433855e+09            actress
# Jurassic World              1.648855e+09  1.433855e+09            actress
# Jurassic World              1.648855e+09  1.433855e+09            actress
# Jurassic World              1.648855e+09  1.433855e+09            actress
# Jurassic World              1.648855e+09  1.433855e+09            actress
# Jurassic World              1.648855e+09  1.433855e+09              actor
# Furious 7                   1.518723e+09  1.328723e+09              actor
# Furious 7                   1.518723e+09  1.328723e+09            actress
# Furious 7                   1.518723e+09  1.328723e+09            actress
# Furious 7                   1.518723e+09  1.328723e+09              actor
# Furious 7                   1.518723e+09  1.328723e+09            actress
# Furious 7                   1.518723e+09  1.328723e+09              actor
# Furious 7                   1.518723e+09  1.328723e+09            actress
# Furious 7                   1.518723e+09  1.328723e+09              actor
# Furious 7                   1.518723e+09  1.328723e+09            actress
# The Avengers                1.517936e+09  1.292936e+09            actress
# The Avengers                1.517936e+09  1.292936e+09            actress
# Avengers: Age of Ultron     1.403014e+09  1.072414e+09            actress
# Avengers: Age of Ultron     1.403014e+09  1.072414e+09            actress
# Avengers: Age of Ultron     1.403014e+09  1.072414e+09              actor
# Avengers: Age of Ultron     1.403014e+09  1.072414e+09            actress
#
#                                  primary_name  averagerating  numvotes
# Avengers: Infinity War           Winston Duke            8.5    670926
# Avengers: Infinity War            Ethan Dizon            8.5    670926
# Avengers: Infinity War        Pom Klementieff            8.5    670926
# Avengers: Infinity War     Tom Vaughan-Lawlor            8.5    670926
# Avengers: Infinity War           Danai Gurira            8.5    670926
# Avengers: Infinity War       Florence Kasumba            8.5    670926
# Avengers: Infinity War           Kerry Condon            8.5    670926
# Avengers: Infinity War          Bobby Hoskins            8.5    670926
# Avengers: Infinity War          Jacob Batalon            8.5    670926
# Jurassic World               Anna Talakkottur            7.0    539338
# Jurassic World                   Chloe Perrin            7.0    539338
# Jurassic World               Kelly Washington            7.0    539338
# Jurassic World           Courtney James Clark            7.0    539338
# Jurassic World                  Katie McGrath            7.0    539338
# Jurassic World                    Ty Simpkins            7.0    539338
# Furious 7                         Lucas Black            7.2    335074
# Furious 7                    Jordana Brewster            7.2    335074
# Furious 7                   Nathalie Emmanuel            7.2    335074
# Furious 7                           Ali Fazal            7.2    335074
# Furious 7                      Brittney Alger            7.2    335074
# Furious 7                        Gentry White            7.2    335074
# Furious 7                       Sasha Casares            7.2    335074
# Furious 7                      Adrian Lockett            7.2    335074
# Furious 7                   Tatiana Bukhahova            7.2    335074
# The Avengers                    Maria Perossa            8.1   1183655
# The Avengers                       Tina Benko            8.1   1183655
# Avengers: Age of Ultron          Edina Loskay            7.3    665594
# Avengers: Age of Ultron      Harriet Manamela            7.3    665594
# Avengers: Age of Ultron         Henry Goodman            7.3    665594
# Avengers: Age of Ultron         Ingvild Deila            7.3    665594

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5782 entries, Avatar to My Date With Drew
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   production_budget  5782 non-null   int32
#  3   domestic_gross     5782 non-null   int32
#  4   worldwide_gross    5782 non-null   float64
#  5   profits            5782 non-null   float64
# dtypes: float64(2), int32(2), int64(1), object(1)
# memory usage: 400.1+ KB

# %%
#Check for seasonality in box office results.
months = []
for i in df3['release_date']:
    newmonth = i[0:3]
    months.append(newmonth)   
months
# Out:
# ['Dec',
#  'May',
#  'Jun',
#  'May',
#  'Dec',
#  'Dec',
#  'Apr',
#  'May',
#  'Nov',
#  'Nov',
#  'Jul',
#  'May',
#  'Jul',
#  'Mar',
#  'Nov',
#  'May',
#  'May',
#  'Mar',
#  'Dec',
#  'Jul',
#  'Dec',
#  'Dec',
#  'Apr',
#  'Jun',
#  'May',
#  'Nov',
#  'May',
#  'Jul',
#  'Jun',
#  'May',
#  'Jul',
#  'May',
#  'Jun',
#  'Jun',
#  'May',
#  'Jun',
#  'Jun',
#  'May',
#  'May',
#  'Dec',
#  'Dec',
#  'Feb',
#  'Dec',
#  'Jun',
#  'Dec',
#  'Jun',
#  'Jun',
#  'May',
#  'May',
#  'Jun',
#  'Mar',
#  'Nov',
#  'Jun',
#  'Mar',
#  'May',
#  'May',
#  'Jun',
#  'Dec',
#  'Nov',
#  'Nov',
#  'May',
#  'Jun',
#  'May',
#  'Jun',
#  'Jun',
#  'Mar',
#  'Apr',
#  'May',
#  'Jun',
#  'May',
#  'Nov',
#  'Jul',
#  'Nov',
#  'May',
#  'Jul',
#  'May',
#  'Jun',
#  'Mar',
#  'Jul',
#  'Oct',
#  'May',
#  'Nov',
#  'Dec',
#  'May',
#  'Nov',
#  'Jun',
#  'Aug',
#  'Jul',
#  'Nov',
#  'Jul',
#  'Feb',
#  'Jul',
#  'May',
#  'Aug',
#  'Jun',
#  'Mar',
#  'Apr',
#  'Jun',
#  'Jul',
#  'Aug',
#  'May',
#  'Nov',
#  'Nov',
#  'Mar',
#  'Jun',
#  'Aug',
#  'Jun',
#  'Aug',
#  'Jun',
#  'Jul',
#  'May',
#  'Dec',
#  'Jun',
#  'Aug',
#  'May',
#  'Apr',
#  'Jul',
#  'Nov',
#  'Jun',
#  'Jul',
#  'May',
#  'Mar',
#  'May',
#  'Feb',
#  'May',
#  'May',
#  'May',
#  'Nov',
#  'Nov',
#  'Mar',
#  'Nov',
#  'Nov',
#  'Jun',
#  'Jul',
#  'Mar',
#  'Dec',
#  'May',
#  'Jul',
#  'Nov',
#  'May',
#  'May',
#  'Jun',
#  'Dec',
#  'Jul',
#  'May',
#  'Jun',
#  'Sep',
#  'Dec',
#  'Jul',
#  'Mar',
#  'Nov',
#  'Jul',
#  'May',
#  'Jul',
#  'Jun',
#  'Nov',
#  'Mar',
#  'Jul',
#  'Nov',
#  'May',
#  'Dec',
#  'Nov',
#  'Jul',
#  'Jul',
#  'Jun',
#  'Nov',
#  'Jun',
#  'Jul',
#  'Jul',
#  'May',
#  'Nov',
#  'May',
#  'May',
#  'May',
#  'May',
#  'May',
#  'Nov',
#  'Mar',
#  'Nov',
#  'May',
#  'May',
#  'May',
#  'Jul',
#  'Nov',
#  'Jul',
#  'Nov',
#  'Mar',
#  'Nov',
#  'May',
#  'Jun',
#  'Feb',
#  'Feb',
#  'Oct',
#  'Mar',
#  'Dec',
#  'Nov',
#  'Jun',
#  'Dec',
#  'Jun',
#  'Jun',
#  'Mar',
#  'Nov',
#  'Apr',
#  'Jul',
#  'Nov',
#  'Jul',
#  'May',
#  'Jul',
#  'Jul',
#  'Jul',
#  'Jan',
#  'Jul',
#  'Mar',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Jul',
#  'Feb',
#  'May',
#  'Mar',
#  'Jul',
#  'Jun',
#  'Jun',
#  'Jul',
#  'Nov',
#  'Mar',
#  'Dec',
#  'Nov',
#  'Mar',
#  'Nov',
#  'Jul',
#  'Jun',
#  'Nov',
#  'Jul',
#  'Nov',
#  'Jun',
#  'Nov',
#  'Nov',
#  'Jun',
#  'Aug',
#  'Jul',
#  'Jun',
#  'Jul',
#  'Mar',
#  'Dec',
#  'Oct',
#  'Nov',
#  'Jul',
#  'Apr',
#  'Jul',
#  'Mar',
#  'Dec',
#  'May',
#  'Nov',
#  'Jul',
#  'Feb',
#  'Nov',
#  'May',
#  'Mar',
#  'Dec',
#  'Jul',
#  'Nov',
#  'Nov',
#  'Nov',
#  'May',
#  'May',
#  'Apr',
#  'Aug',
#  'Dec',
#  'May',
#  'Mar',
#  'Apr',
#  'Nov',
#  'May',
#  'Jun',
#  'Aug',
#  'Jun',
#  'Jul',
#  'Aug',
#  'Dec',
#  'Jan',
#  'Aug',
#  'Nov',
#  'May',
#  'Jun',
#  'Jul',
#  'Jun',
#  'Nov',
#  'Feb',
#  'Apr',
#  'Jun',
#  'Aug',
#  'Apr',
#  'Mar',
#  'Jul',
#  'Feb',
#  'Jun',
#  'Aug',
#  'May',
#  'Jul',
#  'Dec',
#  'Jun',
#  'Oct',
#  'May',
#  'May',
#  'May',
#  'Nov',
#  'Jul',
#  'Feb',
#  'Apr',
#  'Jun',
#  'Jul',
#  'Dec',
#  'Dec',
#  'May',
#  'Oct',
#  'Dec',
#  'Jun',
#  'May',
#  'Jul',
#  'Jun',
#  'Mar',
#  'Dec',
#  'Dec',
#  'Jun',
#  'Mar',
#  'Dec',
#  'Dec',
#  'Jan',
#  'Sep',
#  'Oct',
#  'Jun',
#  'Jul',
#  'Mar',
#  'Jun',
#  'Nov',
#  'Apr',
#  'Jun',
#  'May',
#  'Mar',
#  'Jun',
#  'Jun',
#  'Dec',
#  'Nov',
#  'Dec',
#  'Oct',
#  'Nov',
#  'Jul',
#  'Dec',
#  'Nov',
#  'Mar',
#  'Jul',
#  'Apr',
#  'Sep',
#  'Jun',
#  'May',
#  'May',
#  'Mar',
#  'Jul',
#  'Nov',
#  'Jun',
#  'Dec',
#  'Oct',
#  'Nov',
#  'Jul',
#  'Jun',
#  'Jul',
#  'Nov',
#  'Dec',
#  'Dec',
#  'Jul',
#  'Nov',
#  'Sep',
#  'Aug',
#  'Dec',
#  'Dec',
#  'May',
#  'Jun',
#  'Jun',
#  'Dec',
#  'Aug',
#  'Oct',
#  'Dec',
#  'Jul',
#  'Dec',
#  'Nov',
#  'Jun',
#  'Jun',
#  'Dec',
#  'Sep',
#  'Nov',
#  'Jun',
#  'Dec',
#  'Mar',
#  'Jul',
#  'Aug',
#  'Nov',
#  'Mar',
#  'Oct',
#  'Dec',
#  'Dec',
#  'Apr',
#  'Feb',
#  'Dec',
#  'Aug',
#  'Jan',
#  'Nov',
#  'Feb',
#  'Nov',
#  'May',
#  'Dec',
#  'May',
#  'Mar',
#  'Jul',
#  'Dec',
#  'May',
#  'Feb',
#  'Aug',
#  'Nov',
#  'May',
#  'Mar',
#  'Dec',
#  'Aug',
#  'Feb',
#  'May',
#  'Dec',
#  'Dec',
#  'Jun',
#  'Feb',
#  'Jul',
#  'Aug',
#  'Feb',
#  'Nov',
#  'Feb',
#  'Apr',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Jul',
#  'Nov',
#  'Aug',
#  'Dec',
#  'Jul',
#  'Dec',
#  'Jul',
#  'Apr',
#  'Oct',
#  'Nov',
#  'Jun',
#  'Aug',
#  'Dec',
#  'Jul',
#  'Jun',
#  'May',
#  'Sep',
#  'Dec',
#  'Jun',
#  'Dec',
#  'Jul',
#  'Jun',
#  'Nov',
#  'Aug',
#  'Apr',
#  'Aug',
#  'Jul',
#  'Jun',
#  'Nov',
#  'Apr',
#  'Mar',
#  'Mar',
#  'Dec',
#  'Jul',
#  'Apr',
#  'Mar',
#  'Jul',
#  'Aug',
#  'Oct',
#  'Apr',
#  'Nov',
#  'Dec',
#  'Dec',
#  'May',
#  'Jun',
#  'Sep',
#  'Jul',
#  'Feb',
#  'Jul',
#  'Dec',
#  'Nov',
#  'Dec',
#  'Jul',
#  'Jul',
#  'Apr',
#  'Mar',
#  'Mar',
#  'Sep',
#  'Apr',
#  'Nov',
#  'Feb',
#  'Jul',
#  'Jun',
#  'Dec',
#  'Nov',
#  'Sep',
#  'Nov',
#  'Nov',
#  'Mar',
#  'Dec',
#  'Jun',
#  'Dec',
#  'Mar',
#  'Jun',
#  'Sep',
#  'Nov',
#  'Jan',
#  'Nov',
#  'Jul',
#  'Feb',
#  'Mar',
#  'Jun',
#  'Mar',
#  'Aug',
#  'Mar',
#  'May',
#  'Dec',
#  'Jun',
#  'Jul',
#  'Jul',
#  'Jun',
#  'Dec',
#  'Feb',
#  'Jul',
#  'May',
#  'Aug',
#  'Nov',
#  'Feb',
#  'May',
#  'Mar',
#  'May',
#  'May',
#  'Feb',
#  'Sep',
#  'Jun',
#  'May',
#  'May',
#  'Jun',
#  'May',
#  'Jul',
#  'Dec',
#  'Jun',
#  'Mar',
#  'Feb',
#  'Dec',
#  'Nov',
#  'Jun',
#  'Dec',
#  'Jul',
#  'Feb',
#  'Feb',
#  'Sep',
#  'Jun',
#  'Dec',
#  'Dec',
#  'Jan',
#  'Nov',
#  'Jul',
#  'Nov',
#  'Oct',
#  'Sep',
#  'Feb',
#  'Jul',
#  'Dec',
#  'Aug',
#  'Jun',
#  'May',
#  'Jun',
#  'Dec',
#  'Apr',
#  'Jul',
#  'Nov',
#  'Jun',
#  'Jun',
#  'Mar',
#  'Oct',
#  'Dec',
#  'Oct',
#  'Nov',
#  'Sep',
#  'Jun',
#  'Aug',
#  'Dec',
#  'Apr',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Oct',
#  'Feb',
#  'May',
#  'Nov',
#  'Dec',
#  'Nov',
#  'Apr',
#  'Nov',
#  'Dec',
#  'Nov',
#  'Jan',
#  'Aug',
#  'Sep',
#  'Jun',
#  'Feb',
#  'Nov',
#  'Dec',
#  'Sep',
#  'Oct',
#  'Mar',
#  'Jul',
#  'Aug',
#  'Dec',
#  'Feb',
#  'Jan',
#  'Jul',
#  'Jul',
#  'Jun',
#  'Dec',
#  'Jun',
#  'Jul',
#  'Jul',
#  'Nov',
#  'Dec',
#  'Jun',
#  'May',
#  'Mar',
#  'May',
#  'Jun',
#  'Oct',
#  'Jul',
#  'Jun',
#  'Jun',
#  'Feb',
#  'Jul',
#  'May',
#  'Dec',
#  'Aug',
#  'Jul',
#  'Nov',
#  'Jun',
#  'Feb',
#  'Jul',
#  'Dec',
#  'Dec',
#  'Apr',
#  'Mar',
#  'Dec',
#  'Jun',
#  'Aug',
#  'Mar',
#  'Jul',
#  'Dec',
#  'Oct',
#  'Dec',
#  'Jul',
#  'Mar',
#  'Mar',
#  'Oct',
#  'Jun',
#  'Jun',
#  'Dec',
#  'Oct',
#  'Jan',
#  'Feb',
#  'Aug',
#  'Dec',
#  'Jul',
#  'Feb',
#  'Nov',
#  'Aug',
#  'May',
#  'Aug',
#  'Feb',
#  'Jul',
#  'Feb',
#  'Jul',
#  'Sep',
#  'Jun',
#  'May',
#  'Nov',
#  'Apr',
#  'Dec',
#  'Jun',
#  'Jul',
#  'Jun',
#  'Aug',
#  'May',
#  'Jun',
#  'Dec',
#  'Jun',
#  'Jul',
#  'Aug',
#  'Jun',
#  'Nov',
#  'Aug',
#  'Dec',
#  'Jul',
#  'Aug',
#  'Nov',
#  'Nov',
#  'Dec',
#  'Jun',
#  'Mar',
#  'Mar',
#  'Aug',
#  'Dec',
#  'Mar',
#  'Feb',
#  'Sep',
#  'Dec',
#  'Dec',
#  'Jun',
#  'Jan',
#  'Sep',
#  'Oct',
#  'Sep',
#  'Aug',
#  'Sep',
#  'Jan',
#  'Dec',
#  'Nov',
#  'Aug',
#  'Jun',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Nov',
#  'Jun',
#  'Oct',
#  'Jan',
#  'Oct',
#  'Sep',
#  'Jan',
#  'Feb',
#  'Feb',
#  'Jan',
#  'Apr',
#  'Sep',
#  'Aug',
#  'May',
#  'Jan',
#  'Mar',
#  'May',
#  'Jul',
#  'Jul',
#  'Mar',
#  'Jun',
#  'May',
#  'Jun',
#  'Jul',
#  'Feb',
#  'Nov',
#  'Mar',
#  'Aug',
#  'Nov',
#  'Dec',
#  'Mar',
#  'Oct',
#  'Jun',
#  'Sep',
#  'Aug',
#  'Apr',
#  'Jun',
#  'Mar',
#  'Jul',
#  'Dec',
#  'Nov',
#  'Mar',
#  'Jun',
#  'Mar',
#  'Jul',
#  'Dec',
#  'Nov',
#  'Jun',
#  'Dec',
#  'Dec',
#  'Jun',
#  'Nov',
#  'Jul',
#  'Dec',
#  'Jul',
#  'Aug',
#  'Dec',
#  'May',
#  'Aug',
#  'Feb',
#  'Aug',
#  'Jul',
#  'Dec',
#  'May',
#  'Jul',
#  'Feb',
#  'Feb',
#  'Dec',
#  'Nov',
#  'Dec',
#  'Sep',
#  'Sep',
#  'Mar',
#  'Oct',
#  'Aug',
#  'Oct',
#  'Dec',
#  'Nov',
#  'Nov',
#  'Jan',
#  'Oct',
#  'Jan',
#  'May',
#  'Aug',
#  'Dec',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Oct',
#  'Jul',
#  'Oct',
#  'Dec',
#  'Jun',
#  'Jul',
#  'Apr',
#  'Sep',
#  'Jun',
#  'Aug',
#  'Apr',
#  'Nov',
#  'Dec',
#  'Jun',
#  'Feb',
#  'Oct',
#  'Mar',
#  'Sep',
#  'Aug',
#  'Jan',
#  'Jan',
#  'Feb',
#  'Dec',
#  'Feb',
#  'Mar',
#  'Mar',
#  'Dec',
#  'Dec',
#  'Jun',
#  'Sep',
#  'Jun',
#  'Oct',
#  'Nov',
#  'May',
#  'May',
#  'Jun',
#  'Dec',
#  'Aug',
#  'Jul',
#  'Dec',
#  'Oct',
#  'Apr',
#  'Oct',
#  'Mar',
#  'Jun',
#  'Dec',
#  'Aug',
#  'Dec',
#  'Apr',
#  'Dec',
#  'Sep',
#  'Dec',
#  'May',
#  'Feb',
#  'Oct',
#  'Jul',
#  'Oct',
#  'Jan',
#  'Jun',
#  'Mar',
#  'Apr',
#  'Mar',
#  'Nov',
#  'Apr',
#  'Oct',
#  'May',
#  'Dec',
#  'Dec',
#  'Aug',
#  'Nov',
#  'Dec',
#  'Mar',
#  'Dec',
#  'Sep',
#  'Aug',
#  'Sep',
#  'Jan',
#  'Jul',
#  'Mar',
#  'Dec',
#  'Nov',
#  'Mar',
#  'Oct',
#  'Jan',
#  'Apr',
#  'Oct',
#  'Jun',
#  'Jan',
#  'Dec',
#  'Feb',
#  'Nov',
#  'Mar',
#  'Sep',
#  'Dec',
#  'Apr',
#  'Feb',
#  'Apr',
#  'Sep',
#  'Oct',
#  'Jan',
#  'Apr',
#  'Sep',
#  'Feb',
#  'Dec',
#  'Apr',
#  'Aug',
#  'Nov',
#  'Feb',
#  'May',
#  'Jun',
#  'Apr',
#  'Aug',
#  'Jul',
#  'Jul',
#  'Aug',
#  'Sep',
#  'Mar',
#  'Dec',
#  'Oct',
#  'Jan',
#  'Jan',
#  'Sep',
#  'Feb',
#  'Oct',
#  'Jul',
#  'Aug',
#  'Feb',
#  'Jan',
#  'Jan',
#  'Oct',
#  'Feb',
#  'Dec',
#  'Nov',
#  'Mar',
#  'Jan',
#  'Feb',
#  'Dec',
#  'Oct',
#  'May',
#  'Dec',
#  'Jan',
#  'Sep',
#  'Jun',
#  'Apr',
#  'Apr',
#  'Mar',
#  'Dec',
#  'Dec',
#  'May',
#  'Sep',
#  'Jun',
#  'Oct',
#  'Feb',
#  'May',
#  'Nov',
#  'Aug',
#  'Dec',
#  'Apr',
#  'Mar',
#  'Apr',
#  'Jan',
#  'Jul',
#  'Dec',
#  'Nov',
#  'Feb',
#  'Oct',
#  'Dec',
#  'Jun',
#  'Dec',
#  'Jun',
#  'Feb',
#  'Oct',
#  'Jul',
#  'Aug',
#  'Nov',
#  'Sep',
#  'Feb',
#  'May',
#  'Apr',
#  'Dec',
#  ...]

# %%
df3['releaseMonth']=months

# %%
df3_month = df3.loc[:, ("worldwide_gross",'releaseMonth')]

# %%
df3_month.groupby('releaseMonth').mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='releaseMonth'>

# %%
# No seasonality given low grossing averages in Aug, Jan, high in November, May.

# %% [markdown]
# # Conclusion
# Microsoft should follow these 3 recommedations: a) Microsoft should spend money, but with caution, in order to achieve higher profits, b) Microsoft should target the documentary, comedy and drama genres and the ratings categories of PG-13, PG and R, and c) Microsoft should focus on the movies and actors highlighted above who did well in terms of box office sales and fan ratings.
